# %% [markdown]
# <a href="https://colab.research.google.com/github/abhaysaxena1904/ml-class/blob/master/Audio_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install librosa
# Out:
# ^C

# %%
# !pip install Ipython
# Out:
# ...
# WARNING: Ignoring invalid distribution -umpy (c:\users\91975\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\91975\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\91975\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\91975\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\91975\anaconda3\lib\site-packages)

# %%
import matplotlib.pyplot as plt
import IPython.display as ipd
import librosa
import librosa.display 
from IPython.display import Audio
# %matplotlib inline

# %%
file_name="/content/abhay.wav"

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-0d64de63-4cb1-4887-ab04-5221d4492851" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0d64de63-4cb1-4887-ab04-5221d4492851">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving abhay.wav to abhay.wav

# %%
plt.figure(figsize=(14,5))
data,sample_rate = librosa.load(file_name)
librosa.display.waveplot(data, sr= sample_rate)

ipd.Audio(file_name)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
sample_rate
# Out:
# 22050

# %%
from scipy.io import wavfile as wav
wave_sample_rate, wave_audio = wav.read(file_name)

# %%
wave_sample_rate
# Out:
# 48000

# %%
wave_audio
# Out:
# array([   0,   -1,   -1, ..., -605, -587, -568], dtype=int16)

# %%
plt.figure(figsize=(14,5))
plt.plot(wave_audio)

# %%
data
# Out:
# array([-8.3163031e-06, -3.2572356e-05, -2.9655190e-05, ...,
#        -1.8163346e-02, -1.9926671e-02,  0.0000000e+00], dtype=float32)

# %%
plt.figure(figsize=(14,5))
plt.plot(data)
